# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('./comapre_sorts.csv',sep=",", header=None)

# %%
df.head()
# Out:
#       0          1          2         3          4
# 0  1000  22.046804  23.001909  0.000000  40.601254
# 1  1010  24.961472  23.034573  0.000000  63.523293
# 2  1020  31.092167  30.998707  1.000404  51.986217
# 3  1030  27.221680  28.106213  0.000000  47.043324
# 4  1040  24.566174  24.061441  0.000000  44.989824

# %%
df.columns = ['size', 'Average_Insertion_Sort_Time', 'Average_Selection_Sort_Time','Best_Insertion_Sort_Time','Worst_Insertion_Sort_Time']

# %%
df.head()
# Out:
#    size  Average_Insertion_Sort_Time  Average_Selection_Sort_Time  \
# 0  1000                    22.046804                    23.001909
# 1  1010                    24.961472                    23.034573
# 2  1020                    31.092167                    30.998707
# 3  1030                    27.221680                    28.106213
# 4  1040                    24.566174                    24.061441
#
#    Best_Insertion_Sort_Time  Worst_Insertion_Sort_Time
# 0                  0.000000                  40.601254
# 1                  0.000000                  63.523293
# 2                  1.000404                  51.986217
# 3                  0.000000                  47.043324
# 4                  0.000000                  44.989824

# %%
size = df['size']
insertion_time = df['Average_Insertion_Sort_Time']
selection_time = df['Average_Selection_Sort_Time']
insertion_best_time = df['Best_Insertion_Sort_Time']
insertion_worst_time = df['Worst_Insertion_Sort_Time']

# Plotting the data
fig, ax = plt.subplots()
ax.plot(size, insertion_time, label="Insertion Sort")
ax.plot(size, selection_time, label="Selection Sort")
ax.plot(size, insertion_best_time, label="Insertion Sort (Best Case)")
ax.plot(size, insertion_worst_time, label="Insertion Sort (Worst Case)")

# Adding labels and title
ax.set_xlabel("Array Size")
ax.set_ylabel("Time Taken (ms)")

# Showing the legend
ax.legend()

# Displaying the plot
plt.show()
plt.save("Comaprison-graph.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# Assuming you have already loaded your DataFrame df with the specified columns

# Extracting data from DataFrame columns
size = df['size']
insertion_time = df['Average_Insertion_Sort_Time']
selection_time = df['Average_Selection_Sort_Time']
insertion_best_time = df['Best_Insertion_Sort_Time']
insertion_worst_time = df['Worst_Insertion_Sort_Time']

# Interpolating the data
smooth_size = np.linspace(size.min(), size.max(), 300)  # Generate more points for smoother curve
smooth_insertion_time = interp1d(size, insertion_time, kind='cubic')(smooth_size)
smooth_selection_time = interp1d(size, selection_time, kind='cubic')(smooth_size)
smooth_insertion_best_time = interp1d(size, insertion_best_time, kind='cubic')(smooth_size)
smooth_insertion_worst_time = interp1d(size, insertion_worst_time, kind='cubic')(smooth_size)

# Plotting the data
fig, ax = plt.subplots()
ax.plot(smooth_size, smooth_insertion_time, label="Insertion Sort")
ax.plot(smooth_size, smooth_selection_time, label="Selection Sort")
ax.plot(smooth_size, smooth_insertion_best_time, label="Insertion Sort (Best Case)")
ax.plot(smooth_size, smooth_insertion_worst_time, label="Insertion Sort (Worst Case)")

# Adding labels and title
ax.set_xlabel("Array Size")
ax.set_ylabel("Time Taken (seconds)")

# Showing the legend
ax.legend()

# Displaying the plot
plt.show()
# Out:
# ------------------------------------------------------------------------
# ModuleNotFoundError                    Traceback (most recent call last)
# Cell In[9], line 3
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 from scipy.interpolate import interp1d
#       5 # Assuming you have already loaded your DataFrame df with the specified columns
#       6
#       7 # Extracting data from DataFrame columns
#       8 size = df['size']
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# !pip install scipy
# Out:
# ...
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/ed/6f/ba2b2f14391291dd47d17da78c3ee644fb3a2fd6bddde664381c1968eda9/scipy-1.13.0-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.6 kB 330.3 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.6 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 541.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/45.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/45.9 MB 3.2 MB/s eta 0:00:15
#    ---------------------------------------- 0.2/45.9 MB 3.0 MB/s eta 0:00:16
#    ---------------------------------------- 0.5/45.9 MB 4.0 MB/s eta 0:00:12
#     --------------------------------------- 0.7/45.9 MB 4.5 MB/s eta 0:00:11
#    - -------------------------------------- 1.2/45.9 MB 5.9 MB/s eta 0:00:08
# ...
